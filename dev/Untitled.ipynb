# %%
import brightway2 as bw
import perdu as p

# %%
bw.projects.set_current("US EPA")

# %%
bw.databases
# Out:
# Databases dictionary with 2 object(s):
# 	US LCI
# 	biosphere3

# %%
sorted({p.searching.utils.prepare_query(o['name']) for o in bw.Database("US LCI")})[::20]
# Out:
# ['2,4-d',
#  'Aluminum, secondary, shape casted',
#  'Biodegradable loose fill',
#  'Conditioned log, at plywood plant, US PNW',
#  'Crude oil, extracted',
#  'Electricity, at Grid, ASCC',
#  'Electricity, at eGrid, MROE',
#  'Electricity, at grid, US',
#  'Ethanol, denatured, mixed feedstocks, at conversion facility',
#  'Fuels, burned at coated mechanical paper, average production, at mill',
#  'Harvesting, fresh fruit bunch, at farm',
#  'Lime, agricultural, corn production',
#  'Methylene diphenyl diisocyanate resin, CTR',
#  'Natural gas, processed, m3',
#  'Petroleum refining, at refinery',
#  'Polyethylene, linear low density, resin',
#  'Precision sand casting, aluminum',
#  'Rapeseed, whole plant, at field',
#  'Roundwood, hardwood, average, at forest road, NE-NC',
#  'Roundwood, softwood, green, at mill, NE-NC',
#  'Scanner, department, i5800',
#  'Sodium chloride',
#  'Steel, billets',
#  'Transport, aircraft, freight',
# ...

# %%
sorted({o['name'] for o in bw.Database("US LCI")})
# Out:
# ['2,4-d, at regional storehouse',
#  'Acetic acid, at plant',
#  'Acrylonitrile, at plant',
#  'Acrylonitrile-butadiene-styrene copolymer resin, at plant, CTR',
#  'Acrylonitrile-butadiene-styrene copolymer, resin, at plant',
#  'Alumina, at plant',
#  'Aluminum ingot, production mix, at plant',
#  'Aluminum recovery, transport, to plant',
#  'Aluminum, cold rolling, at plant',
#  'Aluminum, extrusion, at plant',
#  'Aluminum, hot rolling, at plant',
#  'Aluminum, primary ingot, at plant',
#  'Aluminum, primary, ingot, at plant, 1998',
#  'Aluminum, primary, smelt, at plant',
#  'Aluminum, secondary ingot, at plant',
#  'Aluminum, secondary, extruded',
#  'Aluminum, secondary, ingot, at plant, 1998',
#  'Aluminum, secondary, ingot, from automotive scrap, at plant',
#  'Aluminum, secondary, ingot, from beverage cans, at plant',
#  'Aluminum, secondary, rolled',
#  'Aluminum, secondary, shape casted',
#  'Aluminum, sheet, coated, at plant',
# ...
